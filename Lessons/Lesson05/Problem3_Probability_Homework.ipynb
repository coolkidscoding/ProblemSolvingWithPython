# %% [markdown]
# ![](images/ckcslogo.png)

# %% [markdown]
# ### [Cool Kids Coding School](http://www.coolkidscodingschool.com)
# ### Course: Problem Solving With Python
# ### Lesson 5: Problem3-Probability Homework
# ---

# %% [markdown]
# ### Question #1

# %%
# Use the solution we came up with in class and modify it to calculate the empirical probability of rolling a fair 6 
# sided die.

# %% [markdown]
# ## Any Questions?
# ---
# ###### for any questions contact <jimmy@coolkidscodingschool.com>
