# %% [markdown]
# <div>
#
# <p>
# <img align=left src="images/ckcslogo.png">
# </p>
#
# ---
#
# <p>
# <H1 align=left><a href="http://www.coolkidscodingschool.com">Cool Kids Coding School</a></H1>
# <H2 align=left>Course: <strong>Problem Solving with Python</strong></H1>
# <H3 align=left>Lesson 6: <strong>(Homework) Time Series Analysis</strong></H3>
# </p>
#
# </div>
#
# ---

# %% [markdown]
# ### Question #1

# %%
# Modify the in class work to finish the statistics we did not finish in class.
# When complete we will have written code to do the following:
# - Calculate mean
# - Calculate max/min (ie range)
# - Calculate median
# - Calculate return on investment

# Extra Credit: Modify the in class work to calculate the standard deviation of a selected time series.  
# The standard deviation is a measure of how far away from the mean that the values lie.  

# Specifically 
# Step 1: Find the mean.
# Step 2: For each data point, find the square of its distance to the mean.
# Step 3: Sum the values from Step 2.
# Step 4: Divide by the number of data points.
# Step 5: Take the square root.

# You should create a function called CalcStdDeviation that will calculate this value according to the algorithm above.

# %% [markdown]
# $\displaystyle s={\sqrt {\frac {\sum _{i=1}^{N}(x_{i}-{\bar {x}})^{2}}{N}}}$.
#
# where:
# $\displaystyle {N}$ is the number of values we are analyzing
#
# $\displaystyle {x_{i}}$ represents the ith value
#
# $\displaystyle {\bar {x}}$ represents the mean
#
# $\displaystyle {\sum _{i=1}^{N}}$ is the sum of the ith thru N values

# %%
import data.loaddata

symbol = 'GOOG'

# this builtin function displays the time series
data.loaddata.ShowData(symbol)

# this builtin function loads the entire data set
stock_data = data.loaddata.LoadData(symbol)

# this builtin function puts the 'Close' prices in a list
stock_values = data.loaddata.GetValueData(symbol, 'Close')

# %% [markdown]
# ## Any Questions?
# ---
# ###### for any questions contact <hw_help@coolkidscodingschool.com>
