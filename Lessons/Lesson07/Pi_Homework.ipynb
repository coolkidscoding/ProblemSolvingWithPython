# %% [markdown]
# <div>
#
# <p>
# <img align=left src="images/ckcslogo.png">
# </p>
#
# ---
#
# <p>
# <H1 align=left><a href="http://www.coolkidscodingschool.com">Cool Kids Coding School</a></H1>
# <H2 align=left>Course: <strong>Problem Solving with Python</strong></H1>
# <H3 align=left>Lesson 7: <strong>(Homework) Estimating Pi Using Monte Carlo</strong></H3>
# </p>
#
# </div>
#
# ---

# %% [markdown]
# ### Question #1

# %%
# Solution
import data.graphit as graph

graph.GraphIt([],[],[],[])

# Modify the in class work to calculate the number of points we have to generate before the error between our
# estimate of Pi and the actual value is less than

# 0.01
# 0.001

# Hint: What you should do is add a comparison between real pi and your estimate in the code.  When the difference reaches
# the various thresholds note the number of points that have been generated.

# %% [markdown]
# ## Any Questions?
# ---
# ###### for any questions contact <hw_help@coolkidscodingschool.com>
